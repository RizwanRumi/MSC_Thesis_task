# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("images/test.jpg")

# %%
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (720, 1280, 3)

# %%
edit_img = cv2.imread("images/edit_test.jpg")

# %%
plt.imshow(edit_img)

# %%
print(edit_img.shape)
# Out:
# (640, 640, 3)
